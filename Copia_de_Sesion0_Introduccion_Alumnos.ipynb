# %% [markdown]
# <a href="https://colab.research.google.com/github/hectorvilher/AprendizajeAutomaticoPython/blob/main/Copia_de_Sesion0_Introduccion_Alumnos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 Aprendizaje Automático en Python - 2º DAM

# %% [markdown]
# Bienvenidos al módulo de Aprendizaje Automático en Python. Antes de sumergirnos en los algoritmos y el análisis de datos, vamos a conocernos un poco, a dejar configurado nuestro entorno de trabajo para no perder ningún progreso durante el curso y a refrescar los conocimientos básicos que deberíais tener.

# %% [markdown]
# # 📋 0. Encuesta Inicial

# %% [markdown]
# Por favor, ejecuta la siguiente celda e introduce tus datos. Esto me ayudará a adaptar las clases a vuestro perfil y objetivos.

# %%
print("--- ENCUESTA INICIAL DEL ALUMNADO ---")
nombre = input("1. ¿Cuál es tu nombre y apellidos? ")
estudios = input("2. ¿Qué estudios previos tienes (además de 1º de DAM)? ")
futuro = input("3. Al acabar este Grado Superior, ¿prefieres buscar trabajo o seguir estudiando? ")
expectativas = input("4. ¿Qué expectativas tienes de esta asignatura? ")

print(f"\n✅ ¡Gracias, {nombre.split()[0]}! Datos registrados correctamente. Vamos a preparar el entorno.")
# Out:
# --- ENCUESTA INICIAL DEL ALUMNADO ---
# 1. ¿Cuál es tu nombre y apellidos? Héctor del Villar Heras
# 2. ¿Qué estudios previos tienes (además de 1º de DAM)? FPI Calderería y Soldadura
# 3. Al acabar este Grado Superior, ¿prefieres buscar trabajo o seguir estudiando? Estudiar
# 4. ¿Qué expectativas tienes de esta asignatura? Adquirir mas conocimientos
#
# ✅ ¡Gracias, Héctor! Datos registrados correctamente. Vamos a preparar el entorno.

# %% [markdown]
# # 💾 1. Configuración del entorno y persistencia de datos

# %% [markdown]
# ### 1.1. Persistencia de datos mediante Google Drive

# %% [markdown]
# Las máquinas virtuales asociadas a Google Colab son efímeras. Esto significa que cualquier archivo guardado directamente en el disco local de la sesión se eliminará al desconectar el cuaderno. Para garantizar la persistencia de nuestros proyectos y *datasets*, debemos vincular nuestra cuenta de Google Drive (*sobre todo si queremos poder estudiar en casa y aprobar el examen*).

# %%
# Vinculación y montaje del árbol de archivos en Google Drive
from google.colab import drive
drive.mount('/content/drive/')
print("¡Google Drive se ha montado correctamente!")

# Vamos a explorar los contenidos creados utilizando un comando de Linux
# !ls /content/drive/MyDrive/
# Out:
# Mounted at /content/drive
# ¡Google Drive se ha montado correctamente!
#  1758805022918.jpg
#  1.txt
#  2.txt
#  astronauta.drawio
# 'CheatSheet COMPLETA-1.pdf'
# 'chuletario Linux.txt'
# 'Chuletario Powershell.md.txt'
# 'Chuletario Powershell.txt.txt'
# 'Chuletarios SI'
#  Classroom
# 'Colab Notebooks'
# 'Diagrama sin título (1).drawio'
# 'Diagrama sin título (2).drawio'
# 'Diagrama sin título (3).drawio'
# 'Diagrama sin título (4).drawio'
# 'Diagrama sin título.drawio'
#  Ej3_DiagramaDeFlujo.drawio
# 'ej 53.4.drawio'
# 'Ej 6.1 1.drawio'
# 'Ej 6.1 1.drawio.png'
# 'Ej 6.1 2.drawio'
# 'Ej 6.1 2.drawio.png'
# 'Ej 6.1 4.drawio'
#  Ejercicio1DiagramaDeCajasHector.jpg
# 'Ejercicio 2 Bases de Datos SELECT-FUNCIONES Héctor.sql'
# 'imports junit'
# 'Pr ctica 1.I - Ciclo de vida.docx'
#  Rúbrica_Héctor.xlsx
#  RúbricaHéctor.xlsx
# 'VID_20260304_204042 (1).mp4'
# 'VID_20260304_204042 (2).mp4'
#  VID_20260304_204042.mp4
# 'VID_20260304_204148 (1).mp4'
# 'VID_20260304_204148 (2).mp4'
# ...

# %% [markdown]
# Monta tu almacenamiento en Drive dentro de una carpeta con tu nombre y apellidos en el directorio content del sistema de archivos de Google Colab:
#
# (*Si ya se ha ejecutado una acción de montaje en Drive se puede forzar un nuevo montaje con force_remount=True dentro de la función*)

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### 1.2. Control de versiones e integración con GitHub

# %% [markdown]
# Como futuros desarrolladores de *software*, el uso de repositorios que permiten el control de versiones como GitHub es una práctica imprescindible y muy extendida.
#
# Google Colab permite permite trabajar con GitHub de dos formas principales:
#
# 1.   **Guardado directo**: Desde el menú `Archivo > Guardar` una copia en GitHub podemos volcar nuestros cuadernos directamente a un repositorio personal.
# 2.   **Clonado de repositorios**: Mediante comandos de terminal podemos descargar proyectos completos a nuestra máquina virtual.

# %%
# Vamos a clonar un repositorio público directamente al entorno de Colab
# para ello usamos el comando de Linux para realizar el clonado

# !git clone https://github.com/alcarnic/PythonML

# Verificamos los archivos clonados en el directorio actual
# !ls -la ./PythonML
# Out:
# fatal: destination path 'PythonML' already exists and is not an empty directory.
# total 44
# drwxr-xr-x 3 root root  4096 Sep 18 16:46 .
# drwxr-xr-x 1 root root  4096 Sep 18 16:53 ..
# drwxr-xr-x 8 root root  4096 Sep 18 16:46 .git
# -rw-r--r-- 1 root root 18092 Sep 18 16:46 LICENSE
# -rw-r--r-- 1 root root   103 Sep 18 16:46 README.md
# -rw-r--r-- 1 root root  6260 Sep 18 16:46 S0_Introduccion.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Realiza las tareas en la siguiente celda de código utilizando tu cuenta de GitHub:
#
# 1.   Crea un repositorio público para los materiales del módulo
# 2.   Autoriza el acceso de Google Colab a GitHub y guarda este cuaderno en el repositorio recién creado (`Archivo > Guardar una copia en GitHub`)
# 3.   Clona el repositorio en el directorio actual
# 2.   Verifica que los contenidos se han descargado.

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# # 🐍 2. Evaluación Inicial: conocimientos previos de Python

# %% [markdown]
# Como futuros técnicos superiores en DAM, ya estáis acostumbrados a trabajar con lenguajes de programación como Java o C#.
# Ahora vamos a ver cómo se os dan los fundamentos de Python, un lenguaje indispensable hoy en día para entrenar modelos de *Machine Learning* y otros modelos más avanzados, como los de *Deep Learning* usados en el Big Data.

# %% [markdown]
# **Instrucciones:**
#
# *   Lee atentamente los comentarios en cada bloque de código.
# *   Escribe tu código en los espacios indicados con `# TU CÓDIGO AQUÍ`.
# *   Ejecuta cada celda (botón `Play` o `Shift + Enter`) para comprobar si el resultado es el esperado.

# %% [markdown]
# ### Ejercicio 1: variables y tipos de datos

# %% [markdown]
# Al desarrollar una aplicación necesitamos almacenar su configuración básica. En este ejercicio tendrás que definir las variables que controlarán el entorno de nuestra app fictícia.

# %% [markdown]
# 1.   Crea una variable 'api_endpoint' y asígnale la cadena "https://api.miapp.com/v1/users"
# 2.   Crea una variable 'version_app' y asígnale el número decimal 2.5
# 3.   Crea una variable booleana 'modo_oscuro_activado' y asígnale el valor True
# 4. Introduce el siguiente script en tu celda. Si todo es correcto, verás el mensaje con el resultado.
#
#
# ```
# print(f"Iniciando App v{version_app}.")
# print(f"Conectando al backend en: {api_endpoint}")
# print(f"¿Modo oscuro activado?: {modo_oscuro_activado}")
# ```

# %%
api_endpoint = "https://api.miapp.com/v1/users"
version_app = 2.5
modo_oscuro_activado = True

# %% [markdown]
# Ya que en Python se declara y se define una variable al mismo tiempo, y el sistema de tipado es dinámico, en muchas ocasiones necesitamos comprobar el tipado de esta (sobre todo a la hora de depurar código para buscar un bug en nuestro *software*).
#
# Para ello tenemos dos  herramientas:
#
#
# 1.   Utilizar los *Type Hints* al declarar y definir una variable
# 2.   Utilizar el método `type()`.

# %% [markdown]
# 4.   Evalua qué tipo de variables tienen las variables anteriores (pasos 1 a 3)
# 5.   Repite los pasos 1 a 4, declarando un nuevo set de variables y utilizando los *Type Hints*

# %%
# TU CÓDIGO AQUÍ
api_endpoint: str = "https://api.miapp.com/v1/users"
version_app: float = 2.5
modo_oscuro_activado: bool = True
print(type(version_app))
print(type(api_endpoint))
print(type(modo_oscuro_activado))
print(f'{version_app}')
# Out:
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# 2.5

# %% [markdown]
# ### Ejercicio 2: condicionales

# %% [markdown]
# Imagina que estás procesando la respuesta del servidor (*backend*) tras intentar hacer login en tu aplicación.
# En este ejercicio, tendrás que mostrar un mensaje en la interfaz dependiendo del código de estado HTTP recibido

# %% [markdown]
# 1. Crea una variable llamada 'codigo_estado_http' y dale un valor.
# 2. Escribe un bloque condicional que evalúe la anterior variable:
#      - Si es igual a 200, muestra "Login exitoso. Cargando panel principal..."
#     - Si es igual a 401, muestra "Error: Credenciales incorrectas o token expirado."
#      - Para cualquier otro caso, muestra "Error desconocido en el servidor."

# %%
# TU CÓDIGO AQUÍ
codigo_estado_http = 500
if codigo_estado_http == 200:
  print('Login exitoso. Cargando panel principal...')
elif codigo_estado_http == 401:
  print('Error: Credenciales incorrectas o token expirado.')
else:
  print('Error desconocido en el servidor.')
# Out:
# Error desconocido en el servidor.

# %% [markdown]
# ### Ejercicio 3: listas y bucles

# %% [markdown]
# Has descargado de la base de datos una lista con las valoraciones (estrellas del 1 al 5) que han dejado los usuarios sobre tu aplicación en la Play Store.
#
# Quieres contar cuántas valoraciones perfectas (5 estrellas) has recibido. Para ello, tienes que recorrer una lista y contabilizar el número de *hits*.

# %% [markdown]
# 1. Crea y puebla una lista llamada 'valoraciones_playstore'.
# 2. Crea una variable contador llamada 'contador_cinco_estrellas'.
# 3. Recorre, mediante un bucle, la lista 'valoraciones_playstore' y evalúa si la posición actual se corresponde con una valoración de 5 estrellas, y en caso positivo, suma 1 al contador.
# 4. Muestra por pantalla el resultado final utilizando el siguiente script:
#
# ```
# print(f"¡Felicidades! Has recibido {contador_cinco_estrellas} reseñas de 5 estrellas.")
# ```

# %%
# TU CÓDIGO AQUÍ
valoraciones_playstore = [5,4.5,3,5,5,3.5]
contador_cinco_estrellas = 0
for puntuacion in valoraciones_playstore:
  if puntuacion == 5:
    contador_cinco_estrellas +=1
print(f'El numero de reseñas 5 estrellas es {contador_cinco_estrellas}')
# Out:
# El numero de reseñas 5 estrellas es 3

# %% [markdown]
# ### Ejercicio 4: funciones

# %% [markdown]
# Para la tienda digital de tu app ficticia, necesitas una función reutilizable que calcule el precio final de un artículo después de aplicarle un descuento (por ejemplo, por ser usuario Premium).

# %% [markdown]
# 1. Define una función llamada 'calcular_precio_final' que reciba dos parámetros:
#     - precio_base (el precio original del artículo en euros)
#     - descuento_porcentaje (el porcentaje a descontar, ej. 20 para un 20%)
# 2. La función debe el precio final tras aplicársele el descuento.

# %%
# TU CÓDIGO AQUÍ
def calcular_precio_final(precio_base,descuento_porcentaje)-> float:
  precio_final = precio_base - (precio_base * descuento_porcentaje/100)
  return precio_final
calcular_precio_final(200,20)
# Out:
# 160.0

# %% [markdown]
# ### Ejercicio 5: diccionarios (JSON-*like*)

# %% [markdown]
# Para un desarrollador de *software* interactuar con datos en formato JSON es el pan de cada día.
#
# En Python, la estructura equivalente es el diccionario.
#
# Vamos a simular la recepción de los datos del perfil de un usuario desde una API.

# %% [markdown]
# 1. Crea un diccionario llamado 'usuario_app' que simule un JSON con estas claves y valores:
#     - "id_usuario": 1045
#     - "username": "dev_ninja"
#     - "es_premium": False
#
# 2. El usuario acaba de pagar la suscripción.
#     - Modifica el diccionariopara cambiar el valor de "es_premium" a True.
# 3. Añade una nueva clave al diccionario llamada "idioma" y asígnale el valor "es_ES".
# 4. Accede únicamente a la clave "id_usuario" y muestra su valor por pantalla.
#
# **Muestra por pantalla, después de cada paso, los contenidos del diccionario.precedidos del mensaje: "Datos del perfil actualizados: "**

# %%
# TU CÓDIGO AQUÍ
usuario_app = {"id_usuario":1045,"username":"dev_ninja","es_premium":False}

def mostrar_datos(usuario_app):
  print("----Datos del perfil----")
  print()
  for key,dato in usuario_app.items():
    print(key,": " ,dato)
  print()
mostrar_datos(usuario_app)
usuario_app["es_premium"] = True
usuario_app["idioma"] = "es_ES"
print("----Datos actualizados----")
mostrar_datos(usuario_app)

print(usuario_app["id_usuario"])
# Out:
# ----Datos del perfil----
#
# id_usuario :  1045
# username :  dev_ninja
# es_premium :  False
#
# ----Datos actualizados----
# ----Datos del perfil----
#
# id_usuario :  1045
# username :  dev_ninja
# es_premium :  True
# idioma :  es_ES
#
# 1045

# %% [markdown]
# ### Ejercicio 6: tuplas y manipulación de secuencias

# %% [markdown]
# Como desarrollador, y más aún en el campo del *Machine Learning*, a menudo recibimos datos que no deben ser modificados por accidente (como un par de coordenadas GPS o una resolución de pantalla).
#
# Para esto usamos tuplas (son inmutables), a diferencia de las listas (mutables).
#
# Además, en Machine Learning es fundamental saber extraer fragmentos exactos de una secuencia de datos.
#
# En Python, esto se hace de forma muy elegante mediante el *slicing*.

# %% [markdown]
# 1. Imagina que el backend nos devuelve una ruta de reparto como una lista de tuplas. Crea la variable y póblala (al menos 6 entradas diferentes).
# 2. Usa la sintaxis de "slicing" [inicio:fin] para extraer únicamente los valores de los índices 2 a 4 de la ruta de reparto.
#     - Guarda el resultado en la variable 'primeros_puntos' y muéstrala por pantalla.
#     - Comprueba también, mostrándolo por pantalla, la longitud de la variable que almacena los puntos extraídos, para corroborar que únicamente has extraído 3

# %%
# TU CÓDIGO AQUÍ
